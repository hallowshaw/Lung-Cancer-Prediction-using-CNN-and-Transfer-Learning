# %%
# Mount Google Drive to access dataset files
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Define paths to the training, validation, and test datasets
train_folder = '/content/drive/MyDrive/dataset/train'
test_folder = '/content/drive/MyDrive/dataset/test'
validate_folder = '/content/drive/MyDrive/datasetvalid'

# Define paths to the specific classes within the dataset
normal_folder = '/normal'
adenocarcinoma_folder = '/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib'
large_cell_carcinoma_folder = '/large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa'
squamous_cell_carcinoma_folder = '/squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa'

# %%
# Import necessary libraries
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, SpatialDropout2D, Activation, Lambda, Flatten, LSTM
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import utils

print("Libraries Imported")

# Set the image size for resizing
IMAGE_SIZE = (350, 350)

# Initialize the image data generators for training and testing
print("Reading training images from:", train_folder)
print("Reading validation images from:", validate_folder)

train_datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)


# Define the batch size for training
batch_size = 8


# Create the training data generator
train_generator = train_datagen.flow_from_directory(
    train_folder,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    color_mode="rgb",
    class_mode='categorical'
)


# Create the validation data generator
validation_generator = test_datagen.flow_from_directory(
    test_folder,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    color_mode="rgb",
    class_mode='categorical'
)
# Out:
# Libraries Imported
# Reading training images from: /content/drive/MyDrive/dataset/train
# Reading validation images from: /content/drive/MyDrive/datasetvalid
# Found 613 images belonging to 4 classes.
# Found 315 images belonging to 4 classes.

# %%
# Set up callbacks for learning rate reduction, early stopping, and model checkpointing
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

learning_rate_reduction = ReduceLROnPlateau(monitor='loss', patience=5, verbose=2, factor=0.5, min_lr=0.000001)
early_stops = EarlyStopping(monitor='loss', min_delta=0, patience=6, verbose=2, mode='auto')
checkpointer = ModelCheckpoint(filepath='best_model.hdf5', verbose=2, save_best_only=True, save_weights_only=True)

# %%
# Define the number of output classes
OUTPUT_SIZE = 4

# Load a pre-trained model (Xception) without the top layers and freeze its weights
pretrained_model = tf.keras.applications.Xception(weights='imagenet', include_top=False, input_shape=[*IMAGE_SIZE, 3])
pretrained_model.trainable = False

# Create a new model with the pre-trained base and additional layers for classification
model = Sequential()
model.add(pretrained_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(OUTPUT_SIZE, activation='softmax'))

print("Pretrained model used:")
pretrained_model.summary()

print("Final model created:")
model.summary()

# Compile the model with an optimizer, loss function, and evaluation metric
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 3s 0us/step
# Pretrained model used:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 350, 350, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 174, 174, 32)         864       ['input_3[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 174, 174, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 174, 174, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 172, 172, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 172, 172, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 172, 172, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 172, 172, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 172, 172, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 172, 172, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 172, 172, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 172, 172, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_8 (Conv2D)           (None, 86, 86, 128)          8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 86, 86, 128)          0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (Batch  (None, 86, 86, 128)          512       ['conv2d_8[0][0]']
#  Normalization)
#
#  add (Add)                   (None, 86, 86, 128)          0         ['block2_pool[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activ  (None, 86, 86, 128)          0         ['add[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 86, 86, 256)          33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 86, 86, 256)          1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 86, 86, 256)          0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 86, 86, 256)          67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 86, 86, 256)          1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_9 (Conv2D)           (None, 43, 43, 256)          32768     ['add[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 43, 43, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (Bat  (None, 43, 43, 256)          1024      ['conv2d_9[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 43, 43, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 43, 43, 256)          0         ['add_1[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 43, 43, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 43, 43, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 43, 43, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 43, 43, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 43, 43, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_10 (Conv2D)          (None, 22, 22, 728)          186368    ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 22, 22, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (Bat  (None, 22, 22, 728)          2912      ['conv2d_10[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 22, 22, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  block5_sepconv1_act (Activ  (None, 22, 22, 728)          0         ['add_2[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 22, 22, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 22, 22, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 22, 22, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 22, 22, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 22, 22, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 22, 22, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 22, 22, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 22, 22, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_3 (Add)                 (None, 22, 22, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_2[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 22, 22, 728)          0         ['add_3[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 22, 22, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 22, 22, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 22, 22, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 22, 22, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 22, 22, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 22, 22, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 22, 22, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 22, 22, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_4 (Add)                 (None, 22, 22, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_3[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 22, 22, 728)          0         ['add_4[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 22, 22, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 22, 22, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 22, 22, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 22, 22, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 22, 22, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 22, 22, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 22, 22, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 22, 22, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_5 (Add)                 (None, 22, 22, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_4[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 22, 22, 728)          0         ['add_5[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 22, 22, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 22, 22, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 22, 22, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 22, 22, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 22, 22, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 22, 22, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 22, 22, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 22, 22, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_6 (Add)                 (None, 22, 22, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_5[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 22, 22, 728)          0         ['add_6[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 22, 22, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 22, 22, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 22, 22, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 22, 22, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 22, 22, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 22, 22, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 22, 22, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 22, 22, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_7 (Add)                 (None, 22, 22, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_6[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 22, 22, 728)          0         ['add_7[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 22, 22, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 22, 22, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 22, 22, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 22, 22, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 22, 22, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 22, 22, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 22, 22, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 22, 22, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_8 (Add)                 (None, 22, 22, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_7[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 22, 22, 728)          0         ['add_8[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 22, 22, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 22, 22, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 22, 22, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 22, 22, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 22, 22, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 22, 22, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 22, 22, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 22, 22, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_9 (Add)                 (None, 22, 22, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_8[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 22, 22, 728)          0         ['add_9[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 22, 22, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 22, 22, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 22, 22, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 22, 22, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 22, 22, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 22, 22, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 22, 22, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 22, 22, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_10 (Add)                (None, 22, 22, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_9[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 22, 22, 728)          0         ['add_10[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 22, 22, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 22, 22, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 22, 22, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 22, 22, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 22, 22, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_11 (Conv2D)          (None, 11, 11, 1024)         745472    ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 11, 11, 1024)         0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_3 (Bat  (None, 11, 11, 1024)         4096      ['conv2d_11[0][0]']
#  chNormalization)
#
#  add_11 (Add)                (None, 11, 11, 1024)         0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_3[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 11, 11, 1536)         1582080   ['add_11[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 11, 11, 1536)         6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 11, 11, 1536)         0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 11, 11, 2048)         3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 11, 11, 2048)         8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 11, 11, 2048)         0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
# ==================================================================================================
# Total params: 20861480 (79.58 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 20861480 (79.58 MB)
# __________________________________________________________________________________________________
# Final model created:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 11, 11, 2048)      20861480
#
#  global_average_pooling2d_2  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 4)                 8196
#
# =================================================================
# Total params: 20869676 (79.61 MB)
# Trainable params: 8196 (32.02 KB)
# Non-trainable params: 20861480 (79.58 MB)
# _________________________________________________________________

# %%
# Train the model with the training and validation data generators
history = model.fit(
    train_generator,
    steps_per_epoch=25,
    epochs=50,
    callbacks=[learning_rate_reduction, early_stops, checkpointer],
    validation_data=validation_generator,
    validation_steps=20
)

print("Final training accuracy =", history.history['accuracy'][-1])
print("Final testing accuracy =", history.history['val_accuracy'][-1])
# Out:
# Epoch 1/50
# 25/25 [==============================] - ETA: 0s - loss: 1.2235 - accuracy: 0.4467
# Epoch 1: val_loss improved from inf to 1.08683, saving model to best_model.hdf5
# 25/25 [==============================] - 201s 8s/step - loss: 1.2235 - accuracy: 0.4467 - val_loss: 1.0868 - val_accuracy: 0.5437 - lr: 0.0010
# Epoch 2/50
# 25/25 [==============================] - ETA: 0s - loss: 1.0109 - accuracy: 0.5400
# Epoch 2: val_loss improved from 1.08683 to 1.01950, saving model to best_model.hdf5
# 25/25 [==============================] - 251s 10s/step - loss: 1.0109 - accuracy: 0.5400 - val_loss: 1.0195 - val_accuracy: 0.5250 - lr: 0.0010
# Epoch 3/50
# 25/25 [==============================] - ETA: 0s - loss: 0.8993 - accuracy: 0.6200
# Epoch 3: val_loss improved from 1.01950 to 0.86878, saving model to best_model.hdf5
# 25/25 [==============================] - 252s 10s/step - loss: 0.8993 - accuracy: 0.6200 - val_loss: 0.8688 - val_accuracy: 0.5938 - lr: 0.0010
# Epoch 4/50
# 25/25 [==============================] - ETA: 0s - loss: 0.8822 - accuracy: 0.6350
# Epoch 4: val_loss did not improve from 0.86878
# 25/25 [==============================] - 197s 8s/step - loss: 0.8822 - accuracy: 0.6350 - val_loss: 0.9316 - val_accuracy: 0.5188 - lr: 0.0010
# Epoch 5/50
# 25/25 [==============================] - ETA: 0s - loss: 0.8145 - accuracy: 0.6800
# Epoch 5: val_loss improved from 0.86878 to 0.86739, saving model to best_model.hdf5
# 25/25 [==============================] - 198s 8s/step - loss: 0.8145 - accuracy: 0.6800 - val_loss: 0.8674 - val_accuracy: 0.6438 - lr: 0.0010
# Epoch 6/50
# 25/25 [==============================] - ETA: 0s - loss: 0.7517 - accuracy: 0.6599
# Epoch 6: val_loss did not improve from 0.86739
# 25/25 [==============================] - 249s 10s/step - loss: 0.7517 - accuracy: 0.6599 - val_loss: 0.8915 - val_accuracy: 0.5562 - lr: 0.0010
# Epoch 7/50
# 25/25 [==============================] - ETA: 0s - loss: 0.7259 - accuracy: 0.6950
# Epoch 7: val_loss did not improve from 0.86739
# 25/25 [==============================] - 252s 10s/step - loss: 0.7259 - accuracy: 0.6950 - val_loss: 0.8951 - val_accuracy: 0.5688 - lr: 0.0010
# Epoch 8/50
# 25/25 [==============================] - ETA: 0s - loss: 0.6779 - accuracy: 0.7200
# Epoch 8: val_loss improved from 0.86739 to 0.84312, saving model to best_model.hdf5
# 25/25 [==============================] - 252s 10s/step - loss: 0.6779 - accuracy: 0.7200 - val_loss: 0.8431 - val_accuracy: 0.6125 - lr: 0.0010
# Epoch 9/50
# 25/25 [==============================] - ETA: 0s - loss: 0.6481 - accuracy: 0.7500
# Epoch 9: val_loss improved from 0.84312 to 0.84153, saving model to best_model.hdf5
# 25/25 [==============================] - 252s 10s/step - loss: 0.6481 - accuracy: 0.7500 - val_loss: 0.8415 - val_accuracy: 0.6313 - lr: 0.0010
# Epoch 10/50
# 25/25 [==============================] - ETA: 0s - loss: 0.6475 - accuracy: 0.7259
# Epoch 10: val_loss improved from 0.84153 to 0.80178, saving model to best_model.hdf5
# 25/25 [==============================] - 251s 10s/step - loss: 0.6475 - accuracy: 0.7259 - val_loss: 0.8018 - val_accuracy: 0.6187 - lr: 0.0010
# Epoch 11/50
# 25/25 [==============================] - ETA: 0s - loss: 0.6356 - accuracy: 0.7716
# Epoch 11: val_loss did not improve from 0.80178
# 25/25 [==============================] - 197s 8s/step - loss: 0.6356 - accuracy: 0.7716 - val_loss: 0.8815 - val_accuracy: 0.5688 - lr: 0.0010
# Epoch 12/50
# 25/25 [==============================] - ETA: 0s - loss: 0.5816 - accuracy: 0.8050
# Epoch 12: val_loss did not improve from 0.80178
# 25/25 [==============================] - 252s 10s/step - loss: 0.5816 - accuracy: 0.8050 - val_loss: 0.8396 - val_accuracy: 0.5750 - lr: 0.0010
# Epoch 13/50
# 25/25 [==============================] - ETA: 0s - loss: 0.5517 - accuracy: 0.8150
# Epoch 13: val_loss did not improve from 0.80178
# 25/25 [==============================] - 252s 10s/step - loss: 0.5517 - accuracy: 0.8150 - val_loss: 0.8330 - val_accuracy: 0.6313 - lr: 0.0010
# Epoch 14/50
# 25/25 [==============================] - ETA: 0s - loss: 0.5516 - accuracy: 0.7900
# Epoch 14: val_loss improved from 0.80178 to 0.76163, saving model to best_model.hdf5
# 25/25 [==============================] - 252s 10s/step - loss: 0.5516 - accuracy: 0.7900 - val_loss: 0.7616 - val_accuracy: 0.6313 - lr: 0.0010
# Epoch 15/50
# 25/25 [==============================] - ETA: 0s - loss: 0.5298 - accuracy: 0.8528
# Epoch 15: val_loss improved from 0.76163 to 0.73609, saving model to best_model.hdf5
# 25/25 [==============================] - 250s 10s/step - loss: 0.5298 - accuracy: 0.8528 - val_loss: 0.7361 - val_accuracy: 0.6687 - lr: 0.0010
# Epoch 16/50
# 25/25 [==============================] - ETA: 0s - loss: 0.5405 - accuracy: 0.8426
# Epoch 16: val_loss did not improve from 0.73609
# 25/25 [==============================] - 250s 10s/step - loss: 0.5405 - accuracy: 0.8426 - val_loss: 0.7953 - val_accuracy: 0.6313 - lr: 0.0010
# Epoch 17/50
# 25/25 [==============================] - ETA: 0s - loss: 0.5123 - accuracy: 0.8100
# Epoch 17: val_loss did not improve from 0.73609
# 25/25 [==============================] - 251s 10s/step - loss: 0.5123 - accuracy: 0.8100 - val_loss: 0.8120 - val_accuracy: 0.5813 - lr: 0.0010
# Epoch 18/50
# 25/25 [==============================] - ETA: 0s - loss: 0.4888 - accuracy: 0.8579
# Epoch 18: val_loss did not improve from 0.73609
# 25/25 [==============================] - 250s 10s/step - loss: 0.4888 - accuracy: 0.8579 - val_loss: 0.8006 - val_accuracy: 0.6500 - lr: 0.0010
# Epoch 19/50
# 25/25 [==============================] - ETA: 0s - loss: 0.4427 - accuracy: 0.8700
# Epoch 19: val_loss did not improve from 0.73609
# 25/25 [==============================] - 252s 10s/step - loss: 0.4427 - accuracy: 0.8700 - val_loss: 0.9685 - val_accuracy: 0.4688 - lr: 0.0010
# Epoch 20/50
# 25/25 [==============================] - ETA: 0s - loss: 0.4821 - accuracy: 0.8400
# Epoch 20: val_loss did not improve from 0.73609
# 25/25 [==============================] - 252s 10s/step - loss: 0.4821 - accuracy: 0.8400 - val_loss: 0.7840 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 21/50
# 25/25 [==============================] - ETA: 0s - loss: 0.4456 - accuracy: 0.8750
# Epoch 21: val_loss improved from 0.73609 to 0.68694, saving model to best_model.hdf5
# 25/25 [==============================] - 252s 10s/step - loss: 0.4456 - accuracy: 0.8750 - val_loss: 0.6869 - val_accuracy: 0.6625 - lr: 0.0010
# Epoch 22/50
# 25/25 [==============================] - ETA: 0s - loss: 0.4525 - accuracy: 0.8325
# Epoch 22: val_loss did not improve from 0.68694
# 25/25 [==============================] - 251s 10s/step - loss: 0.4525 - accuracy: 0.8325 - val_loss: 0.7965 - val_accuracy: 0.6062 - lr: 0.0010
# Epoch 23/50
# 25/25 [==============================] - ETA: 0s - loss: 0.4823 - accuracy: 0.8450
# Epoch 23: val_loss did not improve from 0.68694
# 25/25 [==============================] - 252s 10s/step - loss: 0.4823 - accuracy: 0.8450 - val_loss: 0.7557 - val_accuracy: 0.6500 - lr: 0.0010
# Epoch 24/50
# 25/25 [==============================] - ETA: 0s - loss: 0.4909 - accuracy: 0.8400
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 24: val_loss did not improve from 0.68694
# 25/25 [==============================] - 199s 8s/step - loss: 0.4909 - accuracy: 0.8400 - val_loss: 0.7473 - val_accuracy: 0.6687 - lr: 0.0010
# Epoch 25/50
# 25/25 [==============================] - ETA: 0s - loss: 0.4361 - accuracy: 0.9000
# Epoch 25: val_loss did not improve from 0.68694
# 25/25 [==============================] - 251s 10s/step - loss: 0.4361 - accuracy: 0.9000 - val_loss: 0.7168 - val_accuracy: 0.6812 - lr: 5.0000e-04
# Epoch 26/50
# 25/25 [==============================] - ETA: 0s - loss: 0.4049 - accuracy: 0.9137
# Epoch 26: val_loss did not improve from 0.68694
# 25/25 [==============================] - 194s 8s/step - loss: 0.4049 - accuracy: 0.9137 - val_loss: 0.7614 - val_accuracy: 0.6687 - lr: 5.0000e-04
# Epoch 27/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3954 - accuracy: 0.9239
# Epoch 27: val_loss did not improve from 0.68694
# 25/25 [==============================] - 195s 8s/step - loss: 0.3954 - accuracy: 0.9239 - val_loss: 0.7319 - val_accuracy: 0.6562 - lr: 5.0000e-04
# Epoch 28/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3891 - accuracy: 0.9000
# Epoch 28: val_loss did not improve from 0.68694
# 25/25 [==============================] - 194s 8s/step - loss: 0.3891 - accuracy: 0.9000 - val_loss: 0.7099 - val_accuracy: 0.6625 - lr: 5.0000e-04
# Epoch 29/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3775 - accuracy: 0.9450
# Epoch 29: val_loss did not improve from 0.68694
# 25/25 [==============================] - 252s 10s/step - loss: 0.3775 - accuracy: 0.9450 - val_loss: 0.7876 - val_accuracy: 0.6062 - lr: 5.0000e-04
# Epoch 30/50
# 25/25 [==============================] - ETA: 0s - loss: 0.4013 - accuracy: 0.9036
# Epoch 30: val_loss did not improve from 0.68694
# 25/25 [==============================] - 192s 8s/step - loss: 0.4013 - accuracy: 0.9036 - val_loss: 0.7355 - val_accuracy: 0.6750 - lr: 5.0000e-04
# Epoch 31/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3815 - accuracy: 0.9086
# Epoch 31: val_loss did not improve from 0.68694
# 25/25 [==============================] - 249s 10s/step - loss: 0.3815 - accuracy: 0.9086 - val_loss: 0.6879 - val_accuracy: 0.6875 - lr: 5.0000e-04
# Epoch 32/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3832 - accuracy: 0.9086
# Epoch 32: val_loss did not improve from 0.68694
# 25/25 [==============================] - 250s 10s/step - loss: 0.3832 - accuracy: 0.9086 - val_loss: 0.7527 - val_accuracy: 0.6812 - lr: 5.0000e-04
# Epoch 33/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3953 - accuracy: 0.8850
# Epoch 33: val_loss did not improve from 0.68694
# 25/25 [==============================] - 251s 10s/step - loss: 0.3953 - accuracy: 0.8850 - val_loss: 0.7347 - val_accuracy: 0.6625 - lr: 5.0000e-04
# Epoch 34/50
# 25/25 [==============================] - ETA: 0s - loss: 0.4209 - accuracy: 0.8950
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 34: val_loss did not improve from 0.68694
# 25/25 [==============================] - 251s 10s/step - loss: 0.4209 - accuracy: 0.8950 - val_loss: 0.7254 - val_accuracy: 0.6750 - lr: 5.0000e-04
# Epoch 35/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3744 - accuracy: 0.9137
# Epoch 35: val_loss did not improve from 0.68694
# 25/25 [==============================] - 249s 10s/step - loss: 0.3744 - accuracy: 0.9137 - val_loss: 0.7610 - val_accuracy: 0.6687 - lr: 2.5000e-04
# Epoch 36/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3922 - accuracy: 0.9239
# Epoch 36: val_loss did not improve from 0.68694
# 25/25 [==============================] - 196s 8s/step - loss: 0.3922 - accuracy: 0.9239 - val_loss: 0.7241 - val_accuracy: 0.6625 - lr: 2.5000e-04
# Epoch 37/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3712 - accuracy: 0.9350
# Epoch 37: val_loss did not improve from 0.68694
# 25/25 [==============================] - 251s 10s/step - loss: 0.3712 - accuracy: 0.9350 - val_loss: 0.7297 - val_accuracy: 0.6562 - lr: 2.5000e-04
# Epoch 38/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3733 - accuracy: 0.9086
# Epoch 38: val_loss improved from 0.68694 to 0.66075, saving model to best_model.hdf5
# 25/25 [==============================] - 252s 10s/step - loss: 0.3733 - accuracy: 0.9086 - val_loss: 0.6608 - val_accuracy: 0.7375 - lr: 2.5000e-04
# Epoch 39/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3951 - accuracy: 0.9086
# Epoch 39: val_loss did not improve from 0.66075
# 25/25 [==============================] - 253s 10s/step - loss: 0.3951 - accuracy: 0.9086 - val_loss: 0.6667 - val_accuracy: 0.6938 - lr: 2.5000e-04
# Epoch 40/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3991 - accuracy: 0.9200
# Epoch 40: val_loss did not improve from 0.66075
# 25/25 [==============================] - 252s 10s/step - loss: 0.3991 - accuracy: 0.9200 - val_loss: 0.7074 - val_accuracy: 0.6938 - lr: 2.5000e-04
# Epoch 41/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3406 - accuracy: 0.9300
# Epoch 41: val_loss did not improve from 0.66075
# 25/25 [==============================] - 200s 8s/step - loss: 0.3406 - accuracy: 0.9300 - val_loss: 0.6961 - val_accuracy: 0.7063 - lr: 2.5000e-04
# Epoch 42/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3566 - accuracy: 0.9543
# Epoch 42: val_loss improved from 0.66075 to 0.65473, saving model to best_model.hdf5
# 25/25 [==============================] - 250s 10s/step - loss: 0.3566 - accuracy: 0.9543 - val_loss: 0.6547 - val_accuracy: 0.7188 - lr: 2.5000e-04
# Epoch 43/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3717 - accuracy: 0.9100
# Epoch 43: val_loss did not improve from 0.65473
# 25/25 [==============================] - 199s 8s/step - loss: 0.3717 - accuracy: 0.9100 - val_loss: 0.6910 - val_accuracy: 0.6750 - lr: 2.5000e-04
# Epoch 44/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3769 - accuracy: 0.8950
# Epoch 44: val_loss did not improve from 0.65473
# 25/25 [==============================] - 251s 10s/step - loss: 0.3769 - accuracy: 0.8950 - val_loss: 0.7216 - val_accuracy: 0.6812 - lr: 2.5000e-04
# Epoch 45/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3448 - accuracy: 0.9400
# Epoch 45: val_loss did not improve from 0.65473
# 25/25 [==============================] - 253s 10s/step - loss: 0.3448 - accuracy: 0.9400 - val_loss: 0.7515 - val_accuracy: 0.6250 - lr: 2.5000e-04
# Epoch 46/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3580 - accuracy: 0.9200
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 46: val_loss did not improve from 0.65473
# 25/25 [==============================] - 254s 10s/step - loss: 0.3580 - accuracy: 0.9200 - val_loss: 0.6665 - val_accuracy: 0.7125 - lr: 2.5000e-04
# Epoch 47/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3642 - accuracy: 0.9300
# Epoch 47: val_loss did not improve from 0.65473
# 25/25 [==============================] - 254s 10s/step - loss: 0.3642 - accuracy: 0.9300 - val_loss: 0.7167 - val_accuracy: 0.6562 - lr: 1.2500e-04
# Epoch 47: early stopping
# Final training accuracy = 0.9300000071525574
# Final testing accuracy = 0.65625

# %%
# Function to display training curves for loss and accuracy
def display_training_curves(training, validation, title, subplot):
    if subplot % 10 == 1:
        plt.subplots(figsize=(10, 10), facecolor='#F0F0F0')
        plt.tight_layout()
    ax = plt.subplot(subplot)
    ax.set_facecolor('#F8F8F8')
    ax.plot(training)
    ax.plot(validation)
    ax.set_title('model ' + title)
    ax.set_ylabel(title)
    ax.set_xlabel('epoch')
    ax.legend(['train', 'valid.'])

# Display training curves for loss and accuracy
display_training_curves(history.history['loss'], history.history['val_loss'], 'loss', 211)
display_training_curves(history.history['accuracy'], history.history['val_accuracy'], 'accuracy', 212)

# %%
# Save the trained model
model.save('/content/drive/MyDrive/dataset/trained_lung_cancer_model.h5')

# %%
# Function to load and preprocess an image for prediction
from tensorflow.keras.preprocessing import image
import numpy as np

# Define a function to load and preprocess the image
def load_and_preprocess_image(img_path, target_size):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0  # Rescale the image like the training images
    return img_array

# Load, preprocess, and predict the class of an image
img_path = '/content/sq.png'
img = load_and_preprocess_image(img_path, IMAGE_SIZE)

# Make a prediction
predictions = model.predict(img)
predicted_class = np.argmax(predictions[0])

# Map the predicted class to the class label
class_labels = list(train_generator.class_indices.keys())
predicted_label = class_labels[predicted_class]

# Print the predicted class
print(f"The image belongs to class: {predicted_label}")

# Display the image with the predicted class
plt.imshow(image.load_img(img_path, target_size=IMAGE_SIZE))
plt.title(f"Predicted: {predicted_label}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step
# The image belongs to class: squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# Define a function to load and preprocess the image
def load_and_preprocess_image(img_path, target_size):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0  # Rescale the image like the training images
    return img_array

# Load an image from your drive
img_path = '/content/ad3.png'
img = load_and_preprocess_image(img_path, IMAGE_SIZE)

# Make a prediction
predictions = model.predict(img)
predicted_class = np.argmax(predictions[0])

# Map the predicted class to the class label
class_labels = list(train_generator.class_indices.keys())
predicted_label = class_labels[predicted_class]

# Print the predicted class
print(f"The image belongs to class: {predicted_label}")

# Display the image
plt.imshow(image.load_img(img_path, target_size=IMAGE_SIZE))
plt.title(f"Predicted: {predicted_label}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 1s 979ms/step
# The image belongs to class: adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# Define a function to load and preprocess the image
def load_and_preprocess_image(img_path, target_size):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0  # Rescale the image like the training images
    return img_array

# Load an image from your drive
img_path = '/content/l3.png'
img = load_and_preprocess_image(img_path, IMAGE_SIZE)

# Make a prediction
predictions = model.predict(img)
predicted_class = np.argmax(predictions[0])

# Map the predicted class to the class label
class_labels = list(train_generator.class_indices.keys())
predicted_label = class_labels[predicted_class]

# Print the predicted class
print(f"The image belongs to class: {predicted_label}")

# Display the image
plt.imshow(image.load_img(img_path, target_size=IMAGE_SIZE))
plt.title(f"Predicted: {predicted_label}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 1s 747ms/step
# The image belongs to class: large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# Define a function to load and preprocess the image
def load_and_preprocess_image(img_path, target_size):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0  # Rescale the image like the training images
    return img_array

# Load an image from your drive
img_path = '/content/n8.jpg'
img = load_and_preprocess_image(img_path, IMAGE_SIZE)

# Make a prediction
predictions = model.predict(img)
predicted_class = np.argmax(predictions[0])

# Map the predicted class to the class label
class_labels = list(train_generator.class_indices.keys())
predicted_label = class_labels[predicted_class]

# Print the predicted class
print(f"The image belongs to class: {predicted_label}")

# Display the image
plt.imshow(image.load_img(img_path, target_size=IMAGE_SIZE))
plt.title(f"Predicted: {predicted_label}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 1s 796ms/step
# The image belongs to class: normal
